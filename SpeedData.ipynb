# %%
import pandas as pd
import os

# %%
speed_path = os.path.join("Resources","Quickestelectriccars_EVDatabase.csv")
speed_df = pd.read_csv(speed_path)

# %%
speed_df.head()
# Out:
#                                    Name  \
# 0                       Tesla Roadster
# 1                   Tesla Model X Plaid
# 2                Porsche Taycan Turbo S
# 3  Porsche Taycan Turbo S Cross Turismo
# 4            Tesla Cybertruck Tri Motor
#
#                                     Subtitle Acceleration  TopSpeed   Range  \
# 0  Battery Electric Vehicle |       200 kWh       2.1 sec  410 km/h  970 km
# 1   Battery Electric Vehicle |       90 kWh       2.6 sec  262 km/h  455 km
# 2  Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
# 3  Battery Electric Vehicle |       83.7 kWh      2.9 sec  250 km/h  380 km
# 4  Battery Electric Vehicle |       200 kWh       3.0 sec  210 km/h  750 km
#
#   Efficiency FastChargeSpeed            Drive  NumberofSeats PriceinGermany  \
# 0  206 Wh/km        920 km/h  All Wheel Drive              4       €215,000
# 1  198 Wh/km        680 km/h  All Wheel Drive              7       €116,990
# ...

# %%
reduced_speed_df = speed_df.drop(columns = ["Subtitle","Drive","NumberofSeats","PriceinGermany","PriceinUK"])
reduced_speed_df.head()
# Out:
#                                    Name Acceleration  TopSpeed   Range  \
# 0                       Tesla Roadster       2.1 sec  410 km/h  970 km
# 1                   Tesla Model X Plaid      2.6 sec  262 km/h  455 km
# 2                Porsche Taycan Turbo S      2.8 sec  260 km/h  390 km
# 3  Porsche Taycan Turbo S Cross Turismo      2.9 sec  250 km/h  380 km
# 4            Tesla Cybertruck Tri Motor      3.0 sec  210 km/h  750 km
#
#   Efficiency FastChargeSpeed
# 0  206 Wh/km        920 km/h
# 1  198 Wh/km        680 km/h
# 2  215 Wh/km        860 km/h
# 3  220 Wh/km        790 km/h
# 4  267 Wh/km        710 km/h

# %%
reduced_speed_df[['Name', 'Make']] = reduced_speed_df['Name'].str.split(' ', 1, expand=True)
reduced_speed_df.head()
# Out:
#       Name Acceleration  TopSpeed   Range Efficiency FastChargeSpeed  \
# 0    Tesla      2.1 sec  410 km/h  970 km  206 Wh/km        920 km/h
# 1    Tesla      2.6 sec  262 km/h  455 km  198 Wh/km        680 km/h
# 2  Porsche      2.8 sec  260 km/h  390 km  215 Wh/km        860 km/h
# 3  Porsche      2.9 sec  250 km/h  380 km  220 Wh/km        790 km/h
# 4    Tesla      3.0 sec  210 km/h  750 km  267 Wh/km        710 km/h
#
#                            Make
# 0                     Roadster
# 1                 Model X Plaid
# 2                Taycan Turbo S
# 3  Taycan Turbo S Cross Turismo
# 4          Cybertruck Tri Motor

# %%
final_speed_df = reduced_speed_df[['Name', 'Make', 'Acceleration','TopSpeed', 'Range','FastChargeSpeed']]
final_speed_df.head()
# Out:
#       Name                          Make Acceleration  TopSpeed   Range  \
# 0    Tesla                     Roadster       2.1 sec  410 km/h  970 km
# 1    Tesla                 Model X Plaid      2.6 sec  262 km/h  455 km
# 2  Porsche                Taycan Turbo S      2.8 sec  260 km/h  390 km
# 3  Porsche  Taycan Turbo S Cross Turismo      2.9 sec  250 km/h  380 km
# 4    Tesla          Cybertruck Tri Motor      3.0 sec  210 km/h  750 km
#
#   FastChargeSpeed
# 0        920 km/h
# 1        680 km/h
# 2        860 km/h
# 3        790 km/h
# 4        710 km/h

# %%
from sqlalchemy import create_engine

# %%
#First create the db schema on Postgres pg admin 4
#DB Name "speed_db"
#Table Names ="EVMODELS" 

connection_string = "postgres:postgres@localhost:5432/speed_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
#Load DataFrames into database
final_speed_df.to_sql(name='EVMODELS', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\katma\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# c:\Users\katma\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# c:\Users\katma\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# c:\Users\katma\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ...

# %%
#check to confirm data has been loaded properly to table and db
pd.read_sql_query('select * from EVMODELS', con=engine).head()
